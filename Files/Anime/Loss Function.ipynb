# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Discriminator Diagram.png', 'Discriminator Loss Graph For Fake Data.png', 'Discriminator Loss Graph For Original Data.png', 'Generator Diagram.png', 'Generator Loss Graph.png', 'Image Enhancement Using SRGAN.ipynb', 'Loss Function.ipynb', 'SRGAN_Loss_Record.npz']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
loss_rec = np.load("SRGAN_Loss_Record.npz")

# %%
dis_real = np.array(loss_rec['a'])
dis_fake = np.array(loss_rec['b'])
gen = np.array(loss_rec['c'])

print(dis_real.shape, dis_fake.shape, gen.shape)
# Out:
# (56,) (56,) (56,)

# %%
plt.figure(figsize=(10,6))
plt.plot(dis_real,color='red')
plt.ylabel("Loss")  
plt.xlabel("Iteration")  
plt.title("Discriminator Loss Graph For Original Data")
plt.savefig("Discriminator Loss Graph For Original Data.png")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(dis_fake,color='red')
plt.ylabel("Loss")  
plt.xlabel("Iteration")  
plt.title("Discriminator Loss Graph For Fake Data")
plt.savefig("Discriminator Loss Graph For Fake Data.png")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(gen,color='red')
plt.ylabel("Loss")  
plt.xlabel("Iteration")  
plt.title("Generator Loss Graph")
plt.savefig("Generator Loss Graph.png")
plt.grid(True)
plt.show()
